# %%
import numpy as np

# %%
import pandas as pd

# %%
#Read the csv file
df = pd.read_csv('Summer_Olympics.csv')

# %%
#Print it
df
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %%
#Length of data frame
len(df)
# Out:
# 31165

# %% [markdown]
# ## DataFrame

# %% [markdown]
# ### Entries with Null values

# %%
df.isnull().sum()
# Out:
# Year          0
# City          0
# Sport         0
# Discipline    0
# Athlete       0
# Country       4
# Gender        0
# Event         0
# Medal         0
# dtype: int64

# %%
refined_df = df.dropna()

# %%
df
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %% [markdown]
# ## Q1. In how many cities Summer Olympics is held so far?

# %%
n = len(refined_df.City.unique())

# %%
print('The number of cities in which Summer Olympics is held are: ',n)
# Out:
# The number of cities in which Summer Olympics is held are:  22

# %% [markdown]
# ## Q2. Which sport is having most number of Gold Medals so far? (Top 5)

# %%
df_gold = refined_df[refined_df.Medal == 'Gold']

# %%
df_gold
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 6      1896  Athens   Aquatics             Swimming
# 9      1896  Athens   Aquatics             Swimming
# 13     1896  Athens  Athletics            Athletics
# ...     ...     ...        ...                  ...
# 31145  2012  London  Wrestling  Wrestling Freestyle
# 31149  2012  London  Wrestling  Wrestling Freestyle
# 31153  2012  London  Wrestling  Wrestling Freestyle
# 31157  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 3             MALOKINIS, Ioannis     GRE    Men  100M Freestyle For Sailors
# 6                  HAJOS, Alfred     HUN    Men             1200M Freestyle
# ...

# %%
gold_medal_list = []

for Sport in df_gold.Sport.unique():
    
    gold_medal_list.append([Sport, len(df_gold[df_gold.Sport == Sport])])

gold_medal_list = pd.DataFrame(gold_medal_list, columns =['Sport','Gold Medals'])

gold_medal_list = gold_medal_list.sort_values(by = 'Gold Medals', ascending = False).head()

gold_medal_list.plot(x = 'Sport', y = 'Gold Medals', kind = 'bar',color = 'gold', figsize = (8,6))

print ("The Sport having most number of gold medals is : ", gold_medal_list.Sport[0])
# Out:
# The Sport having most number of gold medals is :  Aquatics

# %%
gold_medal_list
# Out:
#          Sport  Gold Medals
# 0     Aquatics         1421
# 1    Athletics         1214
# 17      Rowing          890
# 4   Gymnastics          820
# 3      Fencing          552

# %% [markdown]
# ## Q3. Which sport is having most number of medals so far? (Top 5)

# %%
most_medals = []
for m in df['Sport'].unique():
    most_medals.append([m, len(df[df['Sport'] == m])])
most_medals = pd.DataFrame(most_medals, columns = ['Sport', 'Total Medals'])
most_medals = most_medals.sort_values(by = 'Total Medals', ascending = False).head()
most_medals
# Out:
#          Sport  Total Medals
# 0     Aquatics          4170
# 1    Athletics          3638
# 17      Rowing          2667
# 4   Gymnastics          2307
# 3      Fencing          1613

# %%
most_medals.plot(x = 'Sport', y = 'Total Medals', kind = 'bar', color = 'Silver', figsize = (6,6))
# Out:
# <AxesSubplot:xlabel='Sport'>

# %% [markdown]
# ## Q4. Which player has won most number of medals? (Top 5)

# %%
refined_df
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %%
len(refined_df.Athlete.unique())
# Out:
# 22761

# %%
player_with_most_medals = []

for player in refined_df.Athlete.unique():
    
    player_with_most_medals.append([player, len(refined_df[refined_df.Athlete == player])])

player_with_most_medals = pd.DataFrame(player_with_most_medals, columns = ['Athlete','Medals'])

player_with_most_medals = player_with_most_medals.sort_values(by = 'Medals', ascending = False).head()

print ("The Athlete having most number of medals is : ", player_with_most_medals.Athlete[18640])
# Out:
# The Athlete having most number of medals is :  PHELPS, Michael

# %%
player_with_most_medals
# Out:
#                   Athlete  Medals
# 18640     PHELPS, Michael      22
# 7197     LATYNINA, Larisa      18
# 9948   ANDRIANOV, Nikolay      15
# 7201      SHAKHLIN, Boris      13
# 6591         ONO, Takashi      13

# %%
player_with_most_medals.plot(x = 'Athlete', y = 'Medals', kind = 'bar',color='brown',figsize = (7,5))
# Out:
# <AxesSubplot:xlabel='Athlete'>

# %% [markdown]
# ## Q5. Which player has won most number Gold Medals of medals? (Top 5)

# %%
df_gold
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 6      1896  Athens   Aquatics             Swimming
# 9      1896  Athens   Aquatics             Swimming
# 13     1896  Athens  Athletics            Athletics
# ...     ...     ...        ...                  ...
# 31145  2012  London  Wrestling  Wrestling Freestyle
# 31149  2012  London  Wrestling  Wrestling Freestyle
# 31153  2012  London  Wrestling  Wrestling Freestyle
# 31157  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 3             MALOKINIS, Ioannis     GRE    Men  100M Freestyle For Sailors
# 6                  HAJOS, Alfred     HUN    Men             1200M Freestyle
# ...

# %%
x = df[df['Medal'] == 'Gold']

player_gold = []

for i in x['Athlete'].unique():
    
    player_gold.append([i, len(x[x['Athlete'] == i])])
    
player_gold = pd.DataFrame(player_gold, columns = ['Athlete', 'Gold Medals'])

player_gold = player_gold.sort_values(by = 'Gold Medals', ascending = False).head()

# %%
player_gold
# Out:
#                Athlete  Gold Medals
# 6851   PHELPS, Michael           18
# 3320       SPITZ, Mark            9
# 2714  LATYNINA, Larisa            9
# 4630       LEWIS, Carl            9
# 907       NURMI, Paavo            9

# %%
player_gold.plot(x = 'Athlete', y = 'Gold Medals', kind = 'bar', color = 'Blue', figsize = (7,5))
# Out:
# <AxesSubplot:xlabel='Athlete'>

# %% [markdown]
# ## Q6. In which year India won first Gold Medal in Summer Olympics?

# %%
refined_df[refined_df.Country == 'IND']
# Out:
#        Year       City      Sport           Discipline               Athlete  \
# 241    1900      Paris  Athletics            Athletics     PRITCHARD, Norman
# 244    1900      Paris  Athletics            Athletics     PRITCHARD, Norman
# 5512   1928  Amsterdam     Hockey               Hockey  ALLEN, Richard James
# 5513   1928  Amsterdam     Hockey               Hockey           CHAND, Dyan
# 5514   1928  Amsterdam     Hockey               Hockey   GATELEY, Maurice A.
# ...     ...        ...        ...                  ...                   ...
# 29879  2012     London     Boxing               Boxing             KOM, Mary
# 30841  2012     London   Shooting             Shooting         NARANG, Gagan
# 30849  2012     London   Shooting             Shooting          KUMAR, Vijay
# 31111  2012     London  Wrestling  Wrestling Freestyle       DUTT, Yogeshwar
# 31118  2012     London  Wrestling  Wrestling Freestyle         KUMAR, Sushil
#
# ...

# %%
df_gold[df_gold.Country == 'IND']
# Out:
#        Year       City     Sport Discipline                       Athlete  \
# 5512   1928  Amsterdam    Hockey     Hockey          ALLEN, Richard James
# 5513   1928  Amsterdam    Hockey     Hockey                   CHAND, Dyan
# 5514   1928  Amsterdam    Hockey     Hockey           GATELEY, Maurice A.
# 5515   1928  Amsterdam    Hockey     Hockey                   GILL, K. S.
# 5516   1928  Amsterdam    Hockey     Hockey  GOODSIR-CULLEN, William John
# ...     ...        ...       ...        ...                           ...
# 16099  1980     Moscow    Hockey     Hockey                  SINGH, Singh
# 16100  1980     Moscow    Hockey     Hockey               SURINDER, Singh
# 16101  1980     Moscow    Hockey     Hockey           SYLVANUS, Dung Dung
# 16102  1980     Moscow    Hockey     Hockey                  ZAFAR, Zafar
# 28856  2008    Beijing  Shooting   Shooting               BINDRA, Abhinav
#
#       Country Gender                     Event Medal
# ...

# %%
x = df[df['Medal'] == 'Gold']
y = x.loc[x['Country'] == 'IND']
y.iloc[0]
# Out:
# Year                          1928
# City                     Amsterdam
# Sport                       Hockey
# Discipline                  Hockey
# Athlete       ALLEN, Richard James
# Country                        IND
# Gender                         Men
# Event                       Hockey
# Medal                         Gold
# Name: 5512, dtype: object

# %%
print("The year in which India won its first Gold Medal is: ")
y['Year'].iloc[0]
# Out:
# The year in which India won its first Gold Medal is:
# 1928

# %% [markdown]
# ## Q7. Which event is most popular in terms on number of players? (Top 5)

# %%
len(refined_df.Event.unique())
# Out:
# 666

# %%
popular_event = []

for event in refined_df.Event.unique():
    
    popular_event.append([event, len(refined_df[refined_df.Event == event])])

popular_event = pd.DataFrame(popular_event, columns =['Event','No. of players'])

popular_event = popular_event.sort_values(by = 'No. of players', ascending = False).head()

print("The most popular event is : ", popular_event.Event[80])

popular_event
# Out:
# The most popular event is :  Football
#                 Event  No. of players
# 80           Football            1497
# 176            Hockey            1422
# 138  Team Competition            1147
# 327        Basketball            1012
# 337          Handball             973

# %%
popular_event.plot(x = 'Event', y = 'No. of players', kind = 'bar',color = 'Green', figsize = (8,6))
# Out:
# <AxesSubplot:xlabel='Event'>

# %% [markdown]
# ## Q8. Which sport is having most female Gold Medalists? (Top 5)

# %%
df_women = df_gold[df_gold.Gender == 'Women']

# %%
df_women
# Out:
#        Year      City          Sport           Discipline  \
# 417    1900     Paris           Golf                 Golf
# 641    1900     Paris         Tennis               Tennis
# 649    1900     Paris         Tennis               Tennis
# 710    1904  St Louis        Archery              Archery
# 713    1904  St Louis        Archery              Archery
# ...     ...       ...            ...                  ...
# 31081  2012    London  Weightlifting        Weightlifting
# 31097  2012    London      Wrestling  Wrestling Freestyle
# 31105  2012    London      Wrestling  Wrestling Freestyle
# 31113  2012    London      Wrestling  Wrestling Freestyle
# 31121  2012    London      Wrestling  Wrestling Freestyle
#
#                      Athlete Country Gender  \
# 417    ABBOTT, Margaret Ives     USA  Women
# 641        COOPER, Charlotte     GBR  Women
# 649        COOPER, Charlotte     GBR  Women
# 710    HOWELL, Matilda Scott     USA  Women
# ...

# %%
women_gold_medalist = []

for sport in df_women.Sport.unique():
    
    women_gold_medalist.append([sport, len(df_women[df_women.Sport == sport])])

women_gold_medalist = pd.DataFrame(women_gold_medalist, columns =['Sport','Gold Medals'])

women_gold_medalist = women_gold_medalist.sort_values(by = 'Gold Medals', ascending = False).head()

print("The sport having most number of female gold medalists is : ", women_gold_medalist.Sport[4])

women_gold_medalist
# Out:
# The sport having most number of female gold medalists is :  Aquatics
#          Sport  Gold Medals
# 4     Aquatics          589
# 7    Athletics          388
# 8   Gymnastics          268
# 14      Rowing          217
# 11  Volleyball          166

# %%
women_gold_medalist.plot(x = 'Sport', y = 'Gold Medals', kind = 'bar',color = 'pink', figsize = (8,6))
# Out:
# <AxesSubplot:xlabel='Sport'>
